# %% [markdown]
# https://colab.research.google.com/drive/12HkexGppBPttSPa6e8TVehBypWUM4phJ?usp=sharing
# ### Домашнее задание. Часть 2.
#
#
# Вего за эту часть ДЗ можно набрать максимум **8.5 баллов**. Разбиение баллов по каждой из задач представлено непосредственно перед текстом каждой задачи.
#
# **Дедлайн - пятница, 11.12.2020 в 23:59.**
#
# Дедлайн жесткий, сдача после дедлайна - 0 баллов за ДЗ.
#
# Ссылка на ноутбук в колабе: https://colab.research.google.com/drive/18Yom8NjCpK0XAVaO6-RzNs9--foqKtio?usp=sharing
#
# В этой части ДЗ Вам необходимо будет работать с датасетами - все они лежат в репозитории курса, а именно https://github.com/ddvika/Data-Science-School-2020/tree/main/hw_intermediate в папке `"materials"`
#
# а также на гугл диске:
# https://drive.google.com/drive/folders/1mvcBvJ_2341foynNnvmkJh3EJdS4_b4m?usp=sharing
#
# Вы можете обойтись и без скачивания, тк все данные импортируются напрямую из гитхаб

# %% [markdown]
# # Задание 1
# файл 'file_example_XLSX_1000.xlsx' лежит в репозитории и на гугл диске по ссылке выше

# %% [markdown]
# **0.5 point**
#
# - убрать ненужный столбец Unnamed
#
# **0.5 point**
# - Отсортировать людей по возрасту
#
# **0.5 point**
# - разделить людей по полу (сохраните в переменные female, male)
#
# **1 point**
# - построить гистограмму возрастов для мужчин и гистограмму возрастов для женщин

# %%
import pandas as pd
df = pd.read_excel('https://github.com/ddvika/Data-Science-School-2020/blob/main/hw_intermediate/materials/file_example_XLSX_1000.xlsx?raw=true')
df
# Out:
#      Unnamed: 0 First Name   Last Name  ... Age        Date    Id
# 0             1      Dulce       Abril  ...  32  15/10/2017  1562
# 1             2       Mara   Hashimoto  ...  25  16/08/2016  1582
# 2             3     Philip        Gent  ...  36  21/05/2015  2587
# 3             4   Kathleen      Hanner  ...  25  15/10/2017  3549
# 4             5    Nereida     Magwood  ...  58  16/08/2016  2468
# ..          ...        ...         ...  ...  ..         ...   ...
# 995         996       Roma  Lafollette  ...  34  15/10/2017  2654
# 996         997     Felisa        Cail  ...  28  16/08/2016  6525
# 997         998   Demetria       Abbey  ...  32  21/05/2015  3265
# 998         999     Jeromy        Danz  ...  39  15/10/2017  3265
# 999        1000   Rasheeda      Alkire  ...  29  16/08/2016  6125
#
# [1000 rows x 8 columns]

# %%
#Убрать ненужный столбец Unnamed
df1 = df.drop(df.columns[[0]], axis='columns')

# %%
#Отсортировать людей по возрасту
df1 = df1.sort_values(by='Age')
print (df1)
# Out:
#     First Name Last Name  Gender        Country  Age        Date    Id
# 824     Lester   Prothro    Male         France   21  15/10/2017  6574
# 24      Lester   Prothro    Male         France   21  15/10/2017  6574
# 574     Lester   Prothro    Male         France   21  15/10/2017  6574
# 324     Lester   Prothro    Male         France   21  15/10/2017  6574
# 124     Lester   Prothro    Male         France   21  15/10/2017  6574
# ..         ...       ...     ...            ...  ...         ...   ...
# 954    Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 54     Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 654    Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 504    Nereida   Magwood  Female  United States   58  16/08/2016  2468
# 154    Nereida   Magwood  Female  United States   58  16/08/2016  2468
#
# [1000 rows x 7 columns]

# %%
#Разделить людей по полу (сохраните в переменные female, male)
grp = df1.groupby('Gender')
male = grp.get_group('Male')
female = grp.get_group('Female')
print(male)
print (female)
# Out:
#     First Name Last Name Gender        Country  Age        Date    Id
# 824     Lester   Prothro   Male         France   21  15/10/2017  6574
# 24      Lester   Prothro   Male         France   21  15/10/2017  6574
# 574     Lester   Prothro   Male         France   21  15/10/2017  6574
# 324     Lester   Prothro   Male         France   21  15/10/2017  6574
# 124     Lester   Prothro   Male         France   21  15/10/2017  6574
# ..         ...       ...    ...            ...  ...         ...   ...
# 778      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 978      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 678      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 528      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 478      Garth     Gangi   Male  United States   41  16/08/2016  3256
#
# [240 rows x 7 columns]
#     First Name  Last Name  Gender        Country  Age        Date    Id
# 277  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 227  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 77   Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 577  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# 177  Francesca  Beaudreau  Female         France   23  15/10/2017  5412
# ..         ...        ...     ...            ...  ...         ...   ...
# 954    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 54     Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 654    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 504    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 154    Nereida    Magwood  Female  United States   58  16/08/2016  2468
#
# [760 rows x 7 columns]

# %%
#Построить гистограмму возрастов для мужчин и гистограмму возрастов для женщин
#Для мужчин
import matplotlib.pyplot as plt
plt.hist(male['Age'], color = 'blue', edgecolor = 'black')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Для женщин
plt.hist(female['Age'], color = 'red', edgecolor = 'black')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Задание 2

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ddvika/Data-Science-School-2020/main/hw_intermediate/materials/appl_1980_2014.csv')
df
# Out:
#       Unnamed: 0        Date   Open   High    Low  Close     Volume  Adj Close
# 0              0  2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1              1  2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2              2  2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3              3  2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4              4  2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...         ...    ...    ...    ...    ...        ...        ...
# 8460        8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461        8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462        8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463        8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464        8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 8 columns]

# %% [markdown]
# **0.5 point**
# - убрать ненужный столбец Unnamed
#
# **0.5 point**
# - Проверьте тип данных в столбцах
#
# **0.5 point**
# - Преобразуйте столбец Date в тип datetime
#
# **0.5 point**
# - Установите дату в качестве индекса
#
# **0.5 point**
# - Есть ли повторяющиеся даты?
#
# **0.5 point**
# - Получите последний рабочий день каждого месяца
#
# **0.5 point**
# - Какая разница в днях между первым днем и самым давним?
#
# **0.5 point**
# - Сколько месяцев у нас есть в данных?
#
# **0.5 point**
# -  Постройте значение «Adj Close». Установите размер рисунка 13,5 х 9 дюймов.
#
# **Доп. задание (макс балл 1.5)**
# - Придумайте собственные вопросы и ответьте на них. Также можете нарисовать какие-то интересные графики.

# %%
#Убрать ненужный столбец Unnamed
df1 = df.drop(df.columns[[0]], axis='columns')
df1
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %%
#Проверьте тип данных в столбцах
df1.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %%
#Преобразуйте столбец Date в тип datetime
from datetime import date
from datetime import datetime
df1['Date']= pd.to_datetime(df1['Date'])

# %%
#Установите дату в качестве индекса
df1.index = df1['Date']

# %%
#Получите последний рабочий день каждого месяца
df1[(df1['Date'].dt.is_month_end) & (df1['Date'].dt.dayofweek == 4)]
# Out:
#                  Date    Open    High     Low   Close     Volume  Adj Close
# Date
# 2014-02-28 2014-02-28  529.08  532.75  522.12  526.24   92992200      74.76
# 2014-01-31 2014-01-31  495.18  501.53  493.55  500.60  116199300      70.69
# 2013-05-31 2013-05-31  452.50  457.10  449.50  449.73   96075700      62.73
# 2012-11-30 2012-11-30  586.79  588.40  582.68  585.28   97829900      80.63
# 2012-08-31 2012-08-31  667.25  668.60  657.25  665.24   84580300      91.23
# 2011-09-30 2011-09-30  387.12  388.89  381.18  381.32  136910200      52.07
# 2010-12-31 2010-12-31  322.95  323.48  321.31  322.56   48377000      44.04
# 2010-04-30 2010-04-30  269.31  270.57  261.00  261.09  135615900      35.65
# 2009-07-31 2009-07-31  162.99  165.00  162.91  163.39  105634200      22.31
# 2008-10-31 2008-10-31  107.40  110.78  105.14  107.59  414939000      14.69
# 2008-02-29 2008-02-29  129.29  130.21  124.80  125.02  313870200      17.07
# 2007-11-30 2007-11-30  187.34  187.70  179.70  182.22  296950500      24.88
# 2007-08-31 2007-08-31  139.49  139.65  137.41  138.48  219221800      18.91
# 2006-06-30 2006-06-30   57.59   57.75   56.50   57.27  184923900       7.82
# 2006-03-31 2006-03-31   63.25   63.61   62.24   62.72  203839300       8.56
# 2005-09-30 2005-09-30   52.33   53.65   51.88   53.61  132908300       7.32
# 2004-12-31 2004-12-31   64.89   65.00   64.03   64.40   69647200       4.40
# 2004-04-30 2004-04-30   26.71   26.96   25.49   25.78  116625600       1.76
# 2003-10-31 2003-10-31   23.30   23.35   22.78   22.89   54538400       1.56
# 2003-02-28 2003-02-28   14.86   15.09   14.77   15.01   48774600       1.02
# 2003-01-31 2003-01-31   14.19   14.55   14.05   14.36   85306200       0.98
# 2002-05-31 2002-05-31   24.09   24.25   23.28   23.30   91373800       1.59
# 2001-11-30 2001-11-30   20.47   21.44   20.25   21.30   75978000       1.45
# 2001-08-31 2001-08-31   17.73   18.60   17.65   18.55   54226200       1.27
# 2000-06-30 2000-06-30   52.81   54.94   51.69   52.37   80774400       3.58
# 2000-03-31 2000-03-31  127.44  137.25  126.00  135.81  101158400       4.64
# 1999-12-31 1999-12-31  100.94  102.88   99.50  102.81   40952800       3.51
# 1999-04-30 1999-04-30   44.00   47.13   44.00   46.00  368082400       1.57
# 1998-07-31 1998-07-31   36.63   36.75   34.50   34.63   45777200       1.18
# 1997-10-31 1997-10-31   17.38   17.38   16.62   17.03   66771600       0.58
# 1997-02-28 1997-02-28   16.88   16.88   16.25   16.25   30469600       0.55
# 1997-01-31 1997-01-31   16.62   16.62   16.50   16.62   49907200       0.57
# 1996-05-31 1996-05-31   25.63   26.62   25.50   26.13   40661600       0.89
# 1995-06-30 1995-06-30   47.25   47.87   46.12   46.44   41372800       1.58
# 1995-03-31 1995-03-31   35.12   35.62   34.75   35.25   45810800       1.19
# 1994-09-30 1994-09-30   34.12   34.50   33.62   33.69   17925600       1.13
# 1993-12-31 1993-12-31   29.75   30.25   29.25   29.25   40241600       0.97
# 1993-04-30 1993-04-30   50.75   52.50   50.75   51.25   33084800       1.69
# 1992-07-31 1992-07-31   47.25   47.50   46.75   46.75   22677200       1.53
# 1992-01-31 1992-01-31   64.00   65.25   63.50   64.75   36139600       2.11
# 1991-05-31 1991-05-31   47.50   47.75   46.25   47.00   54465600       1.52
# 1990-11-30 1990-11-30   36.25   37.25   36.25   36.75   30377200       1.19
# 1990-08-31 1990-08-31   36.00   37.25   36.00   37.00   24864000       1.19
# 1989-06-30 1989-06-30   40.50   41.75   39.50   41.25   41185200       1.31
# 1989-03-31 1989-03-31   35.00   35.75   34.75   35.62   46337200       1.13
# 1988-09-30 1988-09-30   44.00   44.00   43.25   43.25   23223200       1.36
# 1987-07-31 1987-07-31   41.25   42.00   41.25   41.25   18261600       1.29
# 1986-10-31 1986-10-31   34.25   34.88   34.25   34.62   30324000       0.54
# 1986-02-28 1986-02-28   25.63   25.87   24.88   25.00   31281600       0.39
# 1986-01-31 1986-01-31   23.00   23.25   22.87   23.13   36926400       0.36
# 1985-05-31 1985-05-31   17.62   18.00   17.38   17.38   92355200       0.27
# 1984-11-30 1984-11-30   25.37   25.63   24.62   24.75   27176800       0.39
# 1984-08-31 1984-08-31   27.00   27.13   26.13   26.50   34462400       0.41
# 1983-09-30 1983-09-30   22.75   23.63   22.50   23.13   29467200       0.36
# 1982-12-31 1982-12-31   30.00   30.37   29.87   29.87   12415200       0.47
# 1982-04-30 1982-04-30   14.75   14.87   14.75   14.75   69350400       0.23
# 1981-07-31 1981-07-31   25.00   25.12   25.00   25.00    2738400       0.39

# %%
#Какая разница в днях между первым днем и самым давним?
df1['Date'].max().toordinal() - df1['Date'].min().toordinal()
# Out:
# 12261

# %%
#Сколько месяцев у нас есть в данных?
import numpy as np
(df1['Date'].max() - df1['Date'].min())//np.timedelta64(1, 'M')
# Out:
# 402

# %%
#Постройте значение «Adj Close». Установите размер рисунка 13,5 х 9 дюймов.
adj_close = list(df1['Adj Close'])
date = list(df1['Date'])
plt.figure(figsize = (13.5, 9))
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.plot(date, adj_close)
